# %%
from btseg.processors import ImageToTimesProcessor

# %%
proc = ImageToTimesProcessor()

# %%
proc.run('../data/Outdir/')

# %%
import pandas as pd

df = pd.read_csv('../data/dataset.csv')

# %%
df_ = df.drop('Unnamed: 0', axis=1)
df_
# Out:
#      id                                   slice_path  \
# 0     1   ../data/Outdir\BraTS20_Training_001\94.png
# 1     2   ../data/Outdir\BraTS20_Training_002\88.png
# 2     3  ../data/Outdir\BraTS20_Training_003\153.png
# 3     4  ../data/Outdir\BraTS20_Training_004\148.png
# 4     5  ../data/Outdir\BraTS20_Training_005\154.png
# ..  ...                                          ...
# 95   96   ../data/Outdir\BraTS20_Training_096\94.png
# 96   97   ../data/Outdir\BraTS20_Training_097\84.png
# 97   98  ../data/Outdir\BraTS20_Training_098\107.png
# 98   99  ../data/Outdir\BraTS20_Training_099\148.png
# 99  100   ../data/Outdir\BraTS20_Training_100\86.png
#
#                                          times_series
# 0   [113.03981599418853, 117.15374513859982, 117.2...
# 1   [2.8284271247461903, 2.8284271247461903, 2.828...
# 2   [5.830951894845301, 5.830951894845301, 5.83095...
# 3   [88.05112151472007, 81.15417426109393, 80.2246...
# ...

# %%
import numpy as np
ts = [eval(val) for val in df_['times_series'].values]
ts
# Out:
# [[113.03981599418853,
#   117.15374513859982,
#   117.27318534089538,
#   117.51595636338071,
#   113.7453295744489,
#   111.15754585272202,
#   109.48972554536796,
#   107.8702924812944,
#   108.25894882179486,
#   107.70793842609746,
#   108.41586599755591,
#   108.93117092916977,
#   109.7679370308106,
#   110.3675676999362,
#   111.0,
#   112.00892821556681,
#   113.08846094982458,
#   113.84638773364749,
#   114.63420083029322,
#   115.87061750072795,
#   117.17081547894082,
#   118.53269591129698,
#   117.23907198540937,
#   115.6027681329474,
#   115.24755962709145,
#   114.58621208504974,
#   114.28035701729323,
#   112.89375536317321,
#   111.83022847155415,
#   110.80162453682708,
#   109.80892495603443,
#   108.07404868885037,
#   107.93516572461452,
#   106.30145812734649,
#   106.21675950620975,
#   105.41821474489122,
#   106.07544484940895,
#   107.48023074035522,
#   107.48953437428223,
#   108.97706180660222,
#   109.78615577567146,
#   112.0446339634344,
# ...

# %%
# !pip install -U umap-learn

# %%
import umap
reducer = umap.UMAP()
reducer.fit_transform(ts)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-fa095656169e> in <module>
# ----> 1 import umap
#       2 reducer = umap.UMAP()
#       3 reducer.fit_transform(ts)
#
# ModuleNotFoundError: No module named 'umap'
